# %% [markdown]
# # 📊 Análisis General de Resultados (15 min por instancia)
# Este notebook analiza los resultados obtenidos con CPLEX en 15 minutos por instancia. Se utiliza el archivo `Comparacion_Resultados_15min.xlsx` como fuente principal.

# %%
# 📦 Cargar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set(style='whitegrid')

# %%
# 📁 Cargar archivo de comparación
ruta_archivo = os.path.join("..", "notebooks", "Comparacion_Resultados_15min.xlsx")

df = pd.read_excel(ruta_archivo)
df
# Out:
#    Instancia  Objetivo     Bound  GAP (%)  Tiempo (s)  Soluciones  \
# 0          1    3210.0   3370.50     5.00       12.49          10
# 1          2    3540.0   3716.99     5.00       71.28           6
# 2          3    7130.0   7986.64    12.01      900.22          21
# 3          4    7895.0   8432.32     6.81      900.28          22
# 4          5    9885.0  13479.72    36.37      900.11          24
# 5          6   10850.0  14079.40    29.76      900.03          16
# 6          7    9450.0  17390.65    84.03      900.09          30
# 7          8   10745.0  16803.95    56.39      900.08          29
# 8          9       NaN       NaN      NaN      900.00           0
# 9         10   11840.0  18935.99    59.93      900.13          30
#
#            Estado
# 0  Óptimo con GAP
# 1  Óptimo con GAP
# 2  Tiempo agotado
# 3  Tiempo agotado
# 4  Tiempo agotado
# 5  Tiempo agotado
# 6  Tiempo agotado
# 7  Tiempo agotado
# 8    Sin solución
# 9  Tiempo agotado

# %%
# 📉 Gráfico: GAP por instancia
plt.figure(figsize=(10, 5))
sns.barplot(x='Instancia', y='GAP (%)', data=df, palette='coolwarm')
plt.title('GAP (%) por instancia (15 min)', fontsize=14)
plt.ylabel('GAP (%)')
plt.xlabel('Instancia')
plt.ylim(0, max(df['GAP (%)'].dropna()) + 10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18760\367222404.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Instancia', y='GAP (%)', data=df, palette='coolwarm')

# %%
# 📈 Comparación de objetivos alcanzados
plt.figure(figsize=(10, 5))
sns.barplot(x='Instancia', y='Objetivo', data=df, palette='crest')
plt.title('Objetivo alcanzado por instancia')
plt.ylabel('Valor objetivo')
plt.xlabel('Instancia')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18760\950047632.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Instancia', y='Objetivo', data=df, palette='crest')

# %%
# 🧾 Mostrar resumen estadístico
df.describe()
# Out:
#        Instancia      Objetivo         Bound    GAP (%)  Tiempo (s)  \
# count   10.00000      9.000000      9.000000   9.000000   10.000000
# mean     5.50000   8282.777778  11577.351111  32.811111  728.471000
# std      3.02765   3141.313530   5884.967196  28.706287  362.127821
# min      1.00000   3210.000000   3370.500000   5.000000   12.490000
# 25%      3.25000   7130.000000   7986.640000   6.810000  900.007500
# 50%      5.50000   9450.000000  13479.720000  29.760000  900.085000
# 75%      7.75000  10745.000000  16803.950000  56.390000  900.125000
# max     10.00000  11840.000000  18935.990000  84.030000  900.280000
#
#        Soluciones
# count   10.000000
# mean    18.800000
# std     10.538817
# min      0.000000
# 25%     11.500000
# 50%     21.500000
# 75%     27.750000
# max     30.000000
